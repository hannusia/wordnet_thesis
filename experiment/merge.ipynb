# %%
import pandas as pd

# %%
wn_rel = pd.read_csv("ukr_wn.csv")
wn_rel.head()
# Out:
#                     id_from  \
# 0  omw-en31-oewn-00001740-n
# 1  omw-en31-oewn-00004475-n
# 2  omw-en31-oewn-00037727-n
# 3  omw-en31-oewn-00035498-n
# 4  omw-en31-oewn-00035041-n
#
#                                                id_to               rel  \
# 0  https://uk.wikipedia.org/wiki/%D0%A1%D1%83%D1%...  pwn31_to_uk_wiki
# 1  https://uk.wikipedia.org/wiki/%D0%9E%D1%80%D0%...  pwn31_to_uk_wiki
# 2  https://uk.wikipedia.org/wiki/%D0%A8%D0%B5%D0%...  pwn31_to_uk_wiki
# 3  https://uk.wikipedia.org/wiki/%D0%90%D0%B1%D0%...  pwn31_to_uk_wiki
# 4  https://uk.wikipedia.org/wiki/%D0%9B%D0%B0%D0%...  pwn31_to_uk_wiki
#
#               lemma
# 0              суще
# 1          організм
# 2            шедевр
# 3  абдомінопластика
# 4        лагідність

# %%
wn_rel.shape
# Out:
# (29494, 4)

# %%
wn_rel["id_crop"] = wn_rel["id_from"].apply(lambda x: x[-10:])

# %%
wn_trans = pd.read_csv("wn_translated.csv")
wn_trans.head()
# Out:
#                id     ili     lemma_en  \
# 0  pwn-00006238-v  i21797  expectorate
# 1  pwn-00009140-v  i21813         molt
# 2  pwn-00014735-v  i21840        sleep
# 3  pwn-00109001-n  i35974        smoke
# 4  pwn-00224850-n  i36585  mass murder
#
#                                             gloss_en google_lemma  \
# 0  discharge (phlegm or sputum) from the lungs an...    виплюнути
# 1             cast off hair, skin, horn, or feathers       линяти
# 2                                          be asleep        спати
# 3    (baseball) a pitch thrown with maximum velocity     нагрівач
# 4    the savage and excessive killing of many people     різанина
#
#                                         google_gloss  \
# 0  виділення (мокрота або мокрота) з легенів і з ...
# 1              скидати волосся, шкіру, ріг або пір’я
# 2                                              спати
# 3    (бейсбол) поле, кинуте з максимальною швидкістю
# 4            дике і надмірне вбивство багатьох людей
#
# ...

# %%
wn_trans["id_crop"] = wn_trans["id"].apply(lambda x: x[-10:])

# %%
merged = wn_rel.join(wn_trans.set_index("id_crop"), on="id_crop")
merged.reset_index(drop=True, inplace=True)

# %%
merged.head()
# Out:
#                     id_from  \
# 0  omw-en31-oewn-00001740-n
# 1  omw-en31-oewn-00004475-n
# 2  omw-en31-oewn-00037727-n
# 3  omw-en31-oewn-00035498-n
# 4  omw-en31-oewn-00035041-n
#
#                                                id_to               rel  \
# 0  https://uk.wikipedia.org/wiki/%D0%A1%D1%83%D1%...  pwn31_to_uk_wiki
# 1  https://uk.wikipedia.org/wiki/%D0%9E%D1%80%D0%...  pwn31_to_uk_wiki
# 2  https://uk.wikipedia.org/wiki/%D0%A8%D0%B5%D0%...  pwn31_to_uk_wiki
# 3  https://uk.wikipedia.org/wiki/%D0%90%D0%B1%D0%...  pwn31_to_uk_wiki
# 4  https://uk.wikipedia.org/wiki/%D0%9B%D0%B0%D0%...  pwn31_to_uk_wiki
#
#               lemma     id_crop              id     ili        lemma_en  \
# 0              суще  00001740-n  pwn-00001740-n  i35545          entity
# 1          організм  00004475-n  pwn-00004475-n  i35553        organism
# 2            шедевр  00037727-n  pwn-00037727-n  i35607     masterpiece
# ...

# %%
merged.to_csv("merged.csv", index=False)

# %%
merged[merged["google_lemma"] == "тиротрицин"]
# Out:
#                        id_from  \
# 6805  omw-en31-oewn-04513420-n
#
#                                                   id_to               rel  \
# 6805  https://uk.wikipedia.org/wiki/%D0%A2%D0%B8%D1%...  pwn31_to_uk_wiki
#
#            lemma     id_crop              id     ili     lemma_en  \
# 6805  тиротрицин  04513420-n  pwn-04513420-n  i60691  tyrothricin
#
#                                                gloss_en google_lemma  \
# 6805  a mixture of antibiotics applied locally to in...   тиротрицин
#
#                                            google_gloss  bing_lemma  \
# 6805  суміш антибіотиків, що застосовуються місцево ...  тиротріцин
#
#                                              bing_gloss
# 6805  суміш антибіотиків, що застосовуються локально...

# %%
merged[:6805]
# Out:
#                        id_from  \
# 0     omw-en31-oewn-00001740-n
# 1     omw-en31-oewn-00004475-n
# 2     omw-en31-oewn-00037727-n
# 3     omw-en31-oewn-00035498-n
# 4     omw-en31-oewn-00035041-n
# ...                        ...
# 6800  omw-en31-oewn-04515458-n
# 6801  omw-en31-oewn-04515784-n
# 6802  omw-en31-oewn-04514748-n
# 6803  omw-en31-oewn-04514450-n
# 6804  omw-en31-oewn-04513801-n
#
#                                                   id_to               rel  \
# 0     https://uk.wikipedia.org/wiki/%D0%A1%D1%83%D1%...  pwn31_to_uk_wiki
# 1     https://uk.wikipedia.org/wiki/%D0%9E%D1%80%D0%...  pwn31_to_uk_wiki
# 2     https://uk.wikipedia.org/wiki/%D0%A8%D0%B5%D0%...  pwn31_to_uk_wiki
# 3     https://uk.wikipedia.org/wiki/%D0%90%D0%B1%D0%...  pwn31_to_uk_wiki
# 4     https://uk.wikipedia.org/wiki/%D0%9B%D0%B0%D0%...  pwn31_to_uk_wiki
# ...                                                 ...               ...
# ...

# %%
merged[:6806].to_csv("merged1.csv", index=False)

# %%
merged[6806:13806].to_csv("merged2.csv", index=False)

# %%
merged[13806:20806].to_csv("merged3.csv", index=False)

# %%
merged_new[merged_new["google_lemma"] == "The Eddy"]
# Out:
#                         id_from  \
# 20803  omw-en31-oewn-10968648-n
#
#                                                    id_to               rel  \
# 20803  https://uk.wikipedia.org/wiki/%D0%9C%D0%B5%D1%...  pwn31_to_uk_wiki
#
#                   lemma     id_crop              id     ili lemma_en  \
# 20803  мері бейкер едді  10968648-n  pwn-10968648-n  i94992     Eddy
#
#                                                gloss_en google_lemma  \
# 20803  founder of Christian Science in 1866 (1821-1910)     The Eddy
#
#                                            google_gloss bing_lemma  \
# 20803  засновник християнської науки в 1866 (1821-1910)       Едді
#
#                                              bing_gloss
# 20803  засновник християнської науки в 1866 (1821-1910)

# %%
merged_new[20803:].to_csv("merged4.csv", index=False)
